# %%
import pandas as pd
import openpyxl

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # import dataset __Key ICT indicators for the world and special regions (totals and penetration rates)__

# %%
df_dvpmnt_status = pd.read_excel(r"..\..\Data\RAW\ITU_regional_global_Key_ICT_indicator_aggregates_Nov_2024.xlsx", sheet_name=0)

dfdev = df_dvpmnt_status.copy()

dfdev.head(20)
# Out:
#    Key ICT indicators for the world and special regions (totals and penetration rates)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                       Fixed-telephone subscriptions
# 4                                               World
# 5                                          Low-income
# 6                                 Lower-middle-income
# 7                                 Upper-middle-income
# 8                                         High-income
# 9                    Least Developed Countries (LDCs)
# 10           Land Locked Developing Countries (LLDCs)
# 11              Small Island Developing States (SIDS)
# 12                                                NaN
# 13                      Fixed-broadband subscriptions
# 14                                                NaN
# 15                                              World
# ...

# %%
dfdev.shape
# Out:
# (158, 42)

# %% [markdown]
# # import dataset __Key ICT indicators for the ITU/BDT regions (totals and penetration rates)__

# %%
df_BDT = pd.read_excel(r"..\..\Data\RAW\ITU_regional_global_Key_ICT_indicator_aggregates_Nov_2024.xlsx", sheet_name=1)

dfbdt = df_BDT.copy()

dfbdt.head(20)
# Out:
#    Key ICT indicators for the ITU/BDT regions (totals and penetration rates)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                       Fixed-telephone subscriptions
# 4                                              Africa
# 5                                            Americas
# 6                                         Arab States
# 7                                        Asia-Pacific
# 8                                                 CIS
# 9                                              Europe
# 10                                                NaN
# 11                      Fixed-broadband subscriptions
# 12                                                NaN
# 13                                             Africa
# 14                                           Americas
# 15                                        Arab States
# ...

# %%
dfbdt.shape
# Out:
# (131, 42)

# %% [markdown]
# # import dataset for __Key ICT indicators by urban/rural area (penetration rates)__

# %%
df_urban_rural = pd.read_excel(r"..\..\Data\RAW\ITU_regional_global_Key_ICT_indicator_aggregates_Nov_2024.xlsx", sheet_name=2)

dfur = df_urban_rural.copy()

dfur.head(100)
# Out:
#    Key ICT indicators by urban/rural area (penetration rates) Unnamed: 1  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN              Total
# 3                                                 NaN               2015
# 4   Population covered by a mobile-cellular networ...                NaN
# 5                                               World               94.9
# 6                                          Low-income               80.7
# 7                                 Lower-middle-income               94.4
# 8                                 Upper-middle-income               96.7
# 9                                         High-income               98.5
# 10                   Least Developed Countries (LDCs)               86.9
# 11           Land Locked Developing Countries (LLDCs)               88.7
# ...

# %%
dfur.shape
# Out:
# (114, 33)

# %%
dfur.head(25)
# Out:
#    Key ICT indicators by urban/rural area (penetration rates) Unnamed: 1  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN              Total
# 3                                                 NaN               2015
# 4   Population covered by a mobile-cellular networ...                NaN
# 5                                               World               94.9
# 6                                          Low-income               80.7
# 7                                 Lower-middle-income               94.4
# 8                                 Upper-middle-income               96.7
# 9                                         High-income               98.5
# 10                   Least Developed Countries (LDCs)               86.9
# 11           Land Locked Developing Countries (LLDCs)               88.7
# ...

# %%
subset = dfur.loc[3:11]
subset.set_index(subset.iloc[:,0], inplace=True)
subset.columns = subset.iloc[0,:]
subset.drop(subset.columns[0], axis=1, inplace=True)
subset.drop(subset.index[0:2], inplace=True)
#subset.drop(subset.columns[10:], axis=1, inplace=True)


subset
# Out:
# C:\Users\manht\AppData\Local\Temp\ipykernel_15764\43188380.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset.drop(subset.columns[0], axis=1, inplace=True)
# C:\Users\manht\AppData\Local\Temp\ipykernel_15764\43188380.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset.drop(subset.index[0:2], inplace=True)
# nan                                                 2015  2016.0  2017.0  \
# Key ICT indicators by urban/rural area (penetra...
# World                                               94.9    95.5    96.2
# Low-income                                          80.7    83.1    83.4
# ...

# %% [markdown]
# # import dataset for __Key ICT indicators by gender (penetration rates)__

# %%
df_gender = pd.read_excel(r"..\..\Data\RAW\ITU_regional_global_Key_ICT_indicator_aggregates_Nov_2024.xlsx", sheet_name=3)

dfge = df_gender.copy()

dfge.head(20)
# Out:
#      Key ICT indicators by gender (penetration rates) Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN        NaN         NaN
# 1                                                 NaN        NaN         NaN
# 2                                                 NaN        NaN         NaN
# 3                                                 NaN      Total         NaN
# 4                                                 NaN       2019      2020.0
# 5   Percentage of individuals using the Internet, ...        NaN         NaN
# 6                                               World       52.9        58.6
# 7                                          Low-income       17.2        18.4
# 8                                 Lower-middle-income       33.5        42.9
# 9                                 Upper-middle-income       64.5        70.3
# 10                                        High-income       87.5        88.5
# ...

# %%
dfge.shape
# Out:
# (55, 21)

# %% [markdown]
# # import dataset for __Internet use by age__

# %%
df_age_original = pd.read_excel(r"..\..\Data\RAW\ITU_regional_global_Key_ICT_indicator_aggregates_Nov_2024.xlsx", sheet_name=4)

dfage = df_age_original.copy()

dfage.head(20)
# Out:
#                                   Internet use by age Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN        NaN         NaN
# 1   Percentage of individuals using the Internet, ...        NaN         NaN
# 2                                                 NaN      Total         NaN
# 3                                                 NaN       2021      2022.0
# 4                                               World       61.7        63.7
# 5                                          Low-income       20.9        23.1
# 6                                 Lower-middle-income       46.6        48.8
# 7                                 Upper-middle-income       74.1        76.5
# 8                                         High-income         90        91.1
# 9                    Least Developed Countries (LDCs)       28.3        30.6
# 10           Land Locked Developing Countries (LLDCs)       32.9        35.5
# ...

# %%
dfage.shape
# Out:
# (32, 15)

# %% [markdown]
# summary of my initial working dataframes

# %%
dfdev, dfbdt, dfur, dfge, dfage
# Out:
# (    Key ICT indicators for the world and special regions (totals and penetration rates)  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                        Fixed-telephone subscriptions
#  4                                                World
#  ..                                                 ...
#  153  Income groups are according to the World Bank ...
#  154                                                NaN
#  155                                            Source:
#  156  ITU World Telecommunication/ICT Indicators dat...
#  157  Version November 2024, for Facts and Figures 2024
#
#      Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
#  0          NaN         NaN         NaN         NaN         NaN         NaN
#  1     Millions         NaN         NaN         NaN         NaN         NaN
# ...

# %%
def filter(data: df)->df:
    """
    input: df
    output: df

    creates a new df 
    """
    data.drop(data.columns[1:10], inplace=True, axis=1)
    data.drop(data.index[:2], inplace=True, axis=0)
    data.columns = data.iloc[0]

clean(dfdev)

dfdev
# Out:
# 2                                                  NaN  2014.0  2015.0  \
# 2                                                  NaN  2014.0  2015.0
# 3                        Fixed-telephone subscriptions     NaN     NaN
# 4                                                World  1095.0  1046.0
# 5                                           Low-income     NaN     8.2
# 6                                  Lower-middle-income     NaN    74.0
# ..                                                 ...     ...     ...
# 153  Income groups are according to the World Bank ...     NaN     NaN
# 154                                                NaN     NaN     NaN
# 155                                            Source:     NaN     NaN
# 156  ITU World Telecommunication/ICT Indicators dat...     NaN     NaN
# 157  Version November 2024, for Facts and Figures 2024     NaN     NaN
#
# 2    2016.0  2017.0  2018.0  2019.0  2020.0  2021.0  2022.0  2023.0  2024.0  \
# ...

# %%
dfdev.index
# Out:
# RangeIndex(start=2, stop=158, step=1)
