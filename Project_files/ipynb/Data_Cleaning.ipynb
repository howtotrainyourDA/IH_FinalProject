# %%
import pandas as pd

# %%
df_original = pd.read_csv (r"../../data/RAW/individuals-using-the-internet_1733842191873.csv")

df = df_original.copy()

df.head()
# Out:
#    seriesID seriesCode                      seriesName  seriesParent  \
# 0     11624       i99H  Individuals using the Internet           NaN
# 1     11624       i99H  Individuals using the Internet           NaN
# 2     11624       i99H  Individuals using the Internet           NaN
# 3     11624       i99H  Individuals using the Internet           NaN
# 4     11624       i99H  Individuals using the Internet           NaN
#
#   seriesUnits  entityID entityIso entityName  dataValue  dataYear dataNote  \
# 0           %         4       ABW      Aruba    15.4428      2000      NaN
# 1           %         4       ABW      Aruba    17.1000      2001      NaN
# 2           %         4       ABW      Aruba    18.8000      2002      NaN
# 3           %         4       ABW      Aruba    20.8000      2003      NaN
# 4           %         4       ABW      Aruba    23.0000      2004      NaN
#
#                                        dataSource  \
# ...

# %%
df = df[df["dataYear"].isin(range(2020, 2024))]

# %%
df
# Out:
#       seriesID seriesCode                      seriesName  seriesParent  \
# 57       11624       i99H  Individuals using the Internet           NaN
# 58       11624       i99H  Individuals using the Internet           NaN
# 59       11624       i99H  Individuals using the Internet           NaN
# 80       11624       i99H  Individuals using the Internet           NaN
# 81       11624       i99H  Individuals using the Internet           NaN
# ...        ...        ...                             ...           ...
# 4759     11624       i99H  Individuals using the Internet           NaN
# 4760     11624       i99H  Individuals using the Internet           NaN
# 4770     11624       i99H  Individuals using the Internet           NaN
# 4771     11624       i99H  Individuals using the Internet           NaN
# 4772     11624       i99H  Individuals using the Internet           NaN
#
#      seriesUnits  entityID entityIso    entityName  dataValue  dataYear  \
# ...
